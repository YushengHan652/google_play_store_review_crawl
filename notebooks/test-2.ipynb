# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('google_play_reviews.csv')
df.head(10)
# Out:
#             Product                Company  \
# 0  Digital Medicine  Ochsner Health System
# 1  Digital Medicine  Ochsner Health System
# 2  Digital Medicine  Ochsner Health System
# 3  Digital Medicine  Ochsner Health System
# 4  Digital Medicine  Ochsner Health System
# 5  Digital Medicine  Ochsner Health System
# 6  Digital Medicine  Ochsner Health System
# 7  Digital Medicine  Ochsner Health System
# 8  Digital Medicine  Ochsner Health System
# 9  Digital Medicine  Ochsner Health System
#
#                               review_id  review_title  \
# 0  cc0b6f1e-7c59-44fe-9ff5-07eb946e8be9           NaN
# 1  8302a08d-3830-419a-b862-7b8892b3e9b0           NaN
# 2  272d3da6-47cd-4435-95a3-d478bff2cb78           NaN
# 3  995065fe-13e8-4ad3-b27f-7600c4dc53e5           NaN
# 4  e72c4897-2710-4c59-aaea-754471c39102           NaN
# 5  d7d0b954-c776-498b-b039-4c62ad4fcccc           NaN
# 6  0ff321b3-18ec-4737-9d43-4fba6afb1683           NaN
# ...

# %%
import random
df.drop(columns={'laguage_code', 'country_code'},inplace = True)
df.insert(loc=2, column='year', value=[random.randint(2018, 2025) for _ in range(len(df))])

# %%
df.insert(loc=2, column='year', value=[random.randint(2018, 2025) for _ in range(len(df))])

# %%
df.to_csv('google_play_reviews_clean.csv', index=False, quoting=csv.QUOTE_NONNUMERIC)
